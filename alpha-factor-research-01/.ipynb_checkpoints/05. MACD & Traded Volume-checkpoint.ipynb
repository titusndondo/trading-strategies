# %%
import pandas as pd
import ta
import numpy as np
import pickle
import itertools
from datetime import datetime

from alphalens import utils, plotting, performance, tears

import mlfinlab as ml

from utilities import (
    getIndicator, 
    getForwardReturns, getCleanFactor, addGroupingFactor,
    plotFactorQuantileBars, plotCumulativeReturns, plotQuantileCumulativeReturns,
    InformationTable)

from factor_library import trend, volume

import pyfolio

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %matplotlib inline

# %%
cusumTrainPrices = pickle.load(open('/home/ubuntu/projects/trading/data/cusumTrainPrices.pkl', 'rb'))
target = pickle.load(open('/home/ubuntu/projects/trading/data/binary_target_5_day.pkl', 'rb'))

# %%
cusumTrainPrices['WHL.JO']
# Out:
#                    high          low         open        close     volume  \
# date
# 2013-01-01  6760.160156  6760.160156  6760.160156  6760.160156        0.0
# 2013-01-02  6895.359863  6586.870117  6854.419922  6679.229980  2105298.0
# 2013-01-03  6855.370117  6712.549805  6759.209961  6741.120117  3103630.0
# 2013-01-04  6878.220215  6707.790039  6735.399902  6878.220215  2293156.0
# 2013-01-07  6902.979980  6769.680176  6879.180176  6781.109863  1809340.0
# ...                 ...          ...          ...          ...        ...
# 2017-12-22  6326.000000  6222.000000  6283.000000  6293.000000  1920416.0
# 2017-12-25  6293.000000  6293.000000  6293.000000  6293.000000        0.0
# 2017-12-26  6293.000000  6293.000000  6293.000000  6293.000000        0.0
# 2017-12-27  6360.000000  6242.000000  6290.000000  6329.000000  3542933.0
# 2017-12-29  6535.000000  6370.000000  6400.000000  6515.000000    73001.0
#
#               adj_close  event vertical_barriers         t1  expected_return  \
# date
# 2013-01-01  5069.762207      0               NaT        NaT              NaN
# 2013-01-02  5009.068848      0               NaT        NaT              NaN
# 2013-01-03  5055.483887      0               NaT        NaT              NaN
# 2013-01-04  5158.302246      1        2013-01-09 2013-01-07        -0.010381
# 2013-01-07  5085.473145      0               NaT        NaT              NaN
# ...                 ...    ...               ...        ...              ...
# 2017-12-22  5665.954102      0               NaT        NaT              NaN
# 2017-12-25  5665.954102      0               NaT        NaT              NaN
# 2017-12-26  5665.954102      0               NaT        NaT              NaN
# 2017-12-27  5698.367188      0               NaT        NaT              NaN
# 2017-12-29  5865.833496      0               NaT        NaT              NaN
#
#             label  profit_taking  stop_loss  holding_period
# date
# 2013-01-01    NaN            NaN        NaN             NaN
# 2013-01-02    NaN            NaN        NaN             NaN
# 2013-01-03    NaN            NaN        NaN             NaN
# 2013-01-04   -1.0       0.000002  -0.000002             3.0
# 2013-01-07    NaN            NaN        NaN             NaN
# ...           ...            ...        ...             ...
# 2017-12-22    NaN            NaN        NaN             NaN
# 2017-12-25    NaN            NaN        NaN             NaN
# 2017-12-26    NaN            NaN        NaN             NaN
# 2017-12-27    NaN            NaN        NaN             NaN
# 2017-12-29    NaN            NaN        NaN             NaN
#
# [1297 rows x 14 columns]

# %%
for symbol, data in cusumTrainPrices.items():
    
    data = data[data['event'] == 1]
    cusumTrainPrices[symbol] = data

# %%
trailing_volume_window = 20

# %%
macd_data = getIndicator(
    cusumTrainPrices,
    trend.macdDiff, n_slow = 6, n_fast = 4, n_sign = 3,
    trailing_volume_n = trailing_volume_window
)
macd_data = macd_data.unstack().asfreq('C').stack()
macd_data
# Out:
#                    MACD_diff_4_6
# date       symbol
# 2013-02-18 HLM.JO      -1.792190
# 2013-02-19 HLM.JO      -2.603653
# 2013-02-21 HLM.JO      -3.440057
# 2013-02-25 HLM.JO      -2.084177
# 2013-02-27 HLM.JO      -4.604300
# ...                          ...
# 2017-12-29 TDH.JO       1.523570
#            TKG.JO      14.465021
#            TRU.JO      -1.327323
#            VOD.JO      16.719320
#            ZED.JO       2.574282
#
# [58323 rows x 1 columns]

# %%
forward_returns = getForwardReturns(datas = cusumTrainPrices)
forward_returns
# Out:
#                          1D  event         t1
# date       asset
# 2013-01-04 ACT.JO -0.038855      1 2013-01-07
#            AEE.JO -0.062500      1 2013-01-07
#            AFE.JO  0.060550      1 2013-01-07
#            AFT.JO  0.069900      1 2013-01-07
#            AFX.JO  0.021739      1 2013-01-07
# ...                     ...    ...        ...
# 2017-12-27 TMT.JO       NaN      1 2017-12-28
#            TON.JO       NaN      1 2017-12-28
#            TRU.JO       NaN      1 2017-12-28
#            TWR.JO       NaN      1 2017-12-28
#            WBO.JO       NaN      1 2017-12-28
#
# [89920 rows x 3 columns]

# %%
macd_factor_data = getCleanFactor(macd_data, forward_returns, quantiles = 10)
macd_factor_data
# Out:
# Dropped 0.0% entries from factor data: 0.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
#                             1D    factor  factor_quantile
# date       asset
# 2013-04-15 ACT.JO     0.014118 -2.398241              7.0
# 2013-04-16 ACT.JO     0.000000 -0.399138              7.0
# 2013-04-18 ACT.JO     0.044084 -0.641828              8.0
# 2013-04-19 ACT.JO    -0.011111  1.040696              5.0
# 2013-04-30 ACT.JO    -0.033708  1.756575              4.0
# ...                        ...       ...              ...
# 2017-12-14 STXWDM.JO -0.030055 -2.004452              5.0
# 2017-12-15 STXWDM.JO -0.008451 -3.759333              3.0
# 2017-12-18 STXWDM.JO -0.025284 -5.420287              2.0
# 2017-12-19 STXWDM.JO -0.003206 -7.553342              2.0
# 2017-12-22 STXWDM.JO  0.000000 -2.453181              3.0
#
# [66347 rows x 3 columns]

# %%
InformationTable(macd_factor_data)
# Out:
# Information Analysis
#                      1D
# IC Mean           0.001
# IC Std.           0.184
# Risk-Adjusted IC  0.005
# t-stat(IC)          NaN
# p-value(IC)         NaN
# IC Skew             NaN
# IC Kurtosis         NaN

# %%
plotFactorQuantileBars(macd_factor_data)

plotCumulativeReturns(macd_factor_data[macd_factor_data['factor_quantile'].isin([1, 2, 9, 10])])

plotQuantileCumulativeReturns(macd_factor_data)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/alphalens/performance.py:398: UserWarning: 'freq' not set, using business day calendar
#   UserWarning)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/alphalens/performance.py:398: UserWarning: 'freq' not set, using business day calendar
#   UserWarning)

# %%
train = pd.concat([macd_factor_data['factor_quantile'], target[['label']]], axis = 1).dropna()
X = train.iloc[:, :-1]
y = train['label']
train
# Out:
#                    factor_quantile  label
# date       asset
# 2013-03-01 GRT.JO             10.0    1.0
#            HLM.JO              1.0   -1.0
# 2013-03-05 GRT.JO              1.0    1.0
#            SHP.JO             10.0    1.0
# 2013-03-08 HLM.JO              1.0   -1.0
# ...                            ...    ...
# 2017-12-22 TWR.JO              6.0    1.0
#            WBO.JO             10.0   -1.0
# 2017-12-27 CTA.JO              1.0   -1.0
#            MCZ.JO             10.0    1.0
#            RBP.JO              5.0   -1.0
#
# [66347 rows x 2 columns]

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.calibration import CalibratedClassifierCV

# %%
def checkCV(X, cv, max_train_size):
    ts = TimeSeriesSplit(n_splits = cv, max_train_size = max_train_size)
    for i, (train_index, test_index) in enumerate(ts.split(X.unstack())):
        
        if len(X.unstack().iloc[train_index, ]) >= max_train_size:
            print(f"Fold {i + 1} -------------------------------------------------------")
            print(f"Train: Length = {len(X.unstack().iloc[train_index, ].index)}")
            print(f"Start date: {X.unstack().iloc[train_index, ].index[0].date()}")
            print(f"End date: {X.unstack().iloc[train_index, ].index[-1].date()} \n")

            print(f"Test: Length =  {len(X.unstack().iloc[test_index, ].index)}")
            print(f"Start date: {X.unstack().iloc[test_index, ].index[0].date()}")
            print(f"End date: {X.unstack().iloc[test_index, ].index[-1].date()}")
            print(f"----------------------------------------------------------------")

# %%
checkCV(X, 35, max_train_size = 240)
# Out:
# Fold 7 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-03-13
# End date: 2014-02-26
#
# Test: Length =  33
# Start date: 2014-02-27
# End date: 2014-04-15
# ----------------------------------------------------------------
# Fold 8 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-05-03
# End date: 2014-04-15
#
# Test: Length =  33
# Start date: 2014-04-16
# End date: 2014-06-06
# ----------------------------------------------------------------
# Fold 9 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-06-20
# End date: 2014-06-06
#
# Test: Length =  33
# Start date: 2014-06-09
# End date: 2014-07-24
# ----------------------------------------------------------------
# Fold 10 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-08-06
# End date: 2014-07-24
#
# Test: Length =  33
# Start date: 2014-07-25
# End date: 2014-09-09
# ----------------------------------------------------------------
# Fold 11 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-09-23
# End date: 2014-09-09
#
# Test: Length =  33
# Start date: 2014-09-10
# End date: 2014-10-27
# ----------------------------------------------------------------
# Fold 12 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-11-08
# End date: 2014-10-27
#
# Test: Length =  33
# Start date: 2014-10-28
# End date: 2014-12-11
# ----------------------------------------------------------------
# Fold 13 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-12-30
# End date: 2014-12-11
#
# Test: Length =  33
# Start date: 2014-12-12
# End date: 2015-02-02
# ----------------------------------------------------------------
# Fold 14 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-02-14
# End date: 2015-02-02
#
# Test: Length =  33
# Start date: 2015-02-03
# End date: 2015-03-19
# ----------------------------------------------------------------
# Fold 15 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-04-03
# End date: 2015-03-19
#
# Test: Length =  33
# Start date: 2015-03-20
# End date: 2015-05-11
# ----------------------------------------------------------------
# Fold 16 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-05-27
# End date: 2015-05-11
#
# Test: Length =  33
# Start date: 2015-05-12
# End date: 2015-06-26
# ----------------------------------------------------------------
# Fold 17 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-07-14
# End date: 2015-06-26
#
# Test: Length =  33
# Start date: 2015-06-29
# End date: 2015-08-13
# ----------------------------------------------------------------
# Fold 18 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-08-28
# End date: 2015-08-13
#
# Test: Length =  33
# Start date: 2015-08-14
# End date: 2015-09-30
# ----------------------------------------------------------------
# Fold 19 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-10-15
# End date: 2015-09-30
#
# Test: Length =  33
# Start date: 2015-10-01
# End date: 2015-11-16
# ----------------------------------------------------------------
# Fold 20 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-12-01
# End date: 2015-11-16
#
# Test: Length =  33
# Start date: 2015-11-17
# End date: 2016-01-05
# ----------------------------------------------------------------
# Fold 21 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-01-21
# End date: 2016-01-05
#
# Test: Length =  33
# Start date: 2016-01-06
# End date: 2016-02-19
# ----------------------------------------------------------------
# Fold 22 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-03-09
# End date: 2016-02-19
#
# Test: Length =  33
# Start date: 2016-02-22
# End date: 2016-04-11
# ----------------------------------------------------------------
# Fold 23 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-04-28
# End date: 2016-04-11
#
# Test: Length =  33
# Start date: 2016-04-12
# End date: 2016-05-30
# ----------------------------------------------------------------
# Fold 24 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-06-15
# End date: 2016-05-30
#
# Test: Length =  33
# Start date: 2016-05-31
# End date: 2016-07-15
# ----------------------------------------------------------------
# Fold 25 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-07-31
# End date: 2016-07-15
#
# Test: Length =  33
# Start date: 2016-07-18
# End date: 2016-09-02
# ----------------------------------------------------------------
# Fold 26 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-09-17
# End date: 2016-09-02
#
# Test: Length =  33
# Start date: 2016-09-05
# End date: 2016-10-19
# ----------------------------------------------------------------
# Fold 27 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-11-04
# End date: 2016-10-19
#
# Test: Length =  33
# Start date: 2016-10-20
# End date: 2016-12-05
# ----------------------------------------------------------------
# Fold 28 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-12-22
# End date: 2016-12-05
#
# Test: Length =  33
# Start date: 2016-12-06
# End date: 2017-01-24
# ----------------------------------------------------------------
# Fold 29 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-02-09
# End date: 2017-01-24
#
# Test: Length =  33
# Start date: 2017-01-25
# End date: 2017-03-10
# ----------------------------------------------------------------
# Fold 30 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-03-30
# End date: 2017-03-10
#
# Test: Length =  33
# Start date: 2017-03-13
# End date: 2017-05-03
# ----------------------------------------------------------------
# Fold 31 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-05-18
# End date: 2017-05-03
#
# Test: Length =  33
# Start date: 2017-05-04
# End date: 2017-06-20
# ----------------------------------------------------------------
# Fold 32 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-07-05
# End date: 2017-06-20
#
# Test: Length =  33
# Start date: 2017-06-21
# End date: 2017-08-04
# ----------------------------------------------------------------
# Fold 33 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-08-23
# End date: 2017-08-04
#
# Test: Length =  33
# Start date: 2017-08-07
# End date: 2017-09-21
# ----------------------------------------------------------------
# Fold 34 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-10-07
# End date: 2017-09-21
#
# Test: Length =  33
# Start date: 2017-09-22
# End date: 2017-11-08
# ----------------------------------------------------------------
# Fold 35 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-11-23
# End date: 2017-11-08
#
# Test: Length =  33
# Start date: 2017-11-09
# End date: 2017-12-27
# ----------------------------------------------------------------

# %%
def modelFit(clf, X, y, cv, max_train_size):

    predictions = pd.DataFrame()
    probabilities = pd.DataFrame()
    ts = TimeSeriesSplit(n_splits = cv, max_train_size=max_train_size) # 
    for train_index, test_index in ts.split(X.unstack()):

        
        train_X = X.unstack().iloc[train_index, ].stack()
        train_y = y.unstack().iloc[train_index].stack()

        test_X = X.unstack().iloc[test_index, ].stack()
        test_y = y.unstack().iloc[test_index].stack()
        
        if len(train_X.unstack()) >= max_train_size:
            model = clf
            model.fit(
                train_X, 
                train_y)

            cal_model = CalibratedClassifierCV(model, cv = 'prefit')
            cal_model.fit(train_X, train_y)

            probs = pd.DataFrame(
                cal_model.predict_proba(test_X), 
                columns = cal_model.classes_, 
                index = test_X.index)

            probabilities = pd.concat(
                [probabilities, probs])

            preds = pd.DataFrame(
                model.predict(test_X), 
                columns = ['predictions'], 
                index = test_X.index)
            preds['actual'] = test_y

            predictions = pd.concat(
                [predictions, preds])
    #         print('DONE!!!!!!!!!!!!!!!!!!!!!')
    return predictions, probabilities

# %%
clf = LogisticRegression(random_state=42)
predictions, probabilities = modelFit(clf, X, y, cv = 35, max_train_size = 240)

# %%
probs = probabilities.loc[:, 1] 
probs.name = 'factor'
factor = pd.DataFrame(probs) 
factor.index.set_names(['date', 'symbol'], inplace = True)
factor
# Out:
#                      factor
# date       symbol
# 2014-02-27 ABG.JO  0.502065
#            ACT.JO  0.503713
#            ADH.JO  0.504702
#            ADI.JO  0.503054
#            AFX.JO  0.504372
# ...                     ...
# 2017-12-22 TWR.JO  0.497310
#            WBO.JO  0.499979
# 2017-12-27 CTA.JO  0.493974
#            MCZ.JO  0.499979
#            RBP.JO  0.496643
#
# [57337 rows x 1 columns]

# %%
clf_factor_data = getCleanFactor(factor, forward_returns, quantiles = 5)
clf_factor_data
# Out:
# Dropped 0.0% entries from factor data: 0.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
#                             1D    factor  factor_quantile
# date       asset
# 2014-02-27 ACT.JO    -0.008439  0.503713              3.0
# 2014-03-03 ACT.JO    -0.042553  0.503713              3.0
# 2014-03-07 ACT.JO     0.022222  0.503383              3.0
# 2014-03-20 ACT.JO    -0.036957  0.503383              3.0
# 2014-03-24 ACT.JO    -0.051919  0.504372              4.0
# ...                        ...       ...              ...
# 2017-12-14 STXWDM.JO -0.030055  0.496643              3.0
# 2017-12-15 STXWDM.JO -0.008451  0.495308              2.0
# 2017-12-18 STXWDM.JO -0.025284  0.494641              1.0
# 2017-12-19 STXWDM.JO -0.003206  0.494641              1.0
# 2017-12-22 STXWDM.JO  0.000000  0.495308              2.0
#
# [57337 rows x 3 columns]

# %%
InformationTable(clf_factor_data)
# Out:
# Information Analysis
#                      1D
# IC Mean           0.009
# IC Std.           0.165
# Risk-Adjusted IC  0.054
# t-stat(IC)          NaN
# p-value(IC)         NaN
# IC Skew             NaN
# IC Kurtosis         NaN

# %%
plotFactorQuantileBars(clf_factor_data)

plotCumulativeReturns(clf_factor_data[clf_factor_data['factor_quantile'].isin([1, 5])])

plotQuantileCumulativeReturns(clf_factor_data)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/alphalens/performance.py:398: UserWarning: 'freq' not set, using business day calendar
#   UserWarning)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/alphalens/performance.py:398: UserWarning: 'freq' not set, using business day calendar
#   UserWarning)

# %%
volume_osc_data = getIndicator(
    cusumTrainPrices, 
    volume.getVolumeOsc, periods = 10, 
    trailing_volume_n = trailing_volume_window)
volume_osc_data
# Out:
#                     volume_oscillator20
# date       symbol
# 2013-04-26 ABG.JO          1.861227e+06
# 2013-04-30 ABG.JO          2.322066e+06
# 2013-05-09 ABG.JO          2.418655e+06
# 2013-05-16 ABG.JO          2.251685e+06
# 2013-05-20 ABG.JO          2.506510e+06
# ...                                 ...
# 2017-12-04 ZPLP.JO         1.832404e+05
# 2017-12-07 ZPLP.JO         1.838065e+05
# 2017-12-14 ZPLP.JO         1.665370e+05
# 2017-12-15 ZPLP.JO         1.427515e+05
# 2017-12-20 ZPLP.JO         1.167989e+05
#
# [58323 rows x 1 columns]

# %%
volume_factor_data = getCleanFactor(volume_osc_data, forward_returns, quantiles = 4)
volume_factor_data
# Out:
# Dropped 0.0% entries from factor data: 0.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 35.0%, not exceeded: OK!
#                             1D         factor  factor_quantile
# date       asset
# 2013-04-15 ACT.JO     0.014118  171914.176063              1.0
# 2013-04-16 ACT.JO     0.000000  155763.053142              1.0
# 2013-04-18 ACT.JO     0.044084  138183.588935              1.0
# 2013-04-19 ACT.JO    -0.011111  123112.936401              1.0
# 2013-04-30 ACT.JO    -0.033708  130637.857055              1.0
# ...                        ...            ...              ...
# 2017-12-14 STXWDM.JO -0.030055   80947.290202              1.0
# 2017-12-15 STXWDM.JO -0.008451   78728.873802              1.0
# 2017-12-18 STXWDM.JO -0.025284   87193.624020              1.0
# 2017-12-19 STXWDM.JO -0.003206   86503.692380              1.0
# 2017-12-22 STXWDM.JO  0.000000   71989.748311              1.0
#
# [66347 rows x 3 columns]

# %%
if 'group' not in macd_factor_data.columns:
    macd_factor_data = addGroupingFactor(macd_factor_data, volume_factor_data)
else:
    macd_factor_data.drop('group', axis = 1, inplace = True)
    macd_factor_data = addGroupingFactor(macd_factor_data, volume_factor_data)
macd_factor_data
# Out:
#                             1D    factor  factor_quantile  group
# date       asset
# 2013-04-15 ACT.JO     0.014118 -2.398241              7.0    1.0
# 2013-04-16 ACT.JO     0.000000 -0.399138              7.0    1.0
# 2013-04-18 ACT.JO     0.044084 -0.641828              8.0    1.0
# 2013-04-19 ACT.JO    -0.011111  1.040696              5.0    1.0
# 2013-04-30 ACT.JO    -0.033708  1.756575              4.0    1.0
# ...                        ...       ...              ...    ...
# 2017-12-14 STXWDM.JO -0.030055 -2.004452              5.0    1.0
# 2017-12-15 STXWDM.JO -0.008451 -3.759333              3.0    1.0
# 2017-12-18 STXWDM.JO -0.025284 -5.420287              2.0    1.0
# 2017-12-19 STXWDM.JO -0.003206 -7.553342              2.0    1.0
# 2017-12-22 STXWDM.JO  0.000000 -2.453181              3.0    1.0
#
# [66347 rows x 4 columns]

# %%
plotFactorQuantileBars(macd_factor_data, by_group = True, group_adjust = False)

# %%
train = pd.concat([macd_factor_data['factor_quantile'], volume_factor_data['factor_quantile'],
                   target[['label']]], axis = 1).dropna()
X = train.iloc[:, :-1]
y = train['label']
train
# Out:
#                    factor_quantile  group  label
# date       asset
# 2013-03-01 GRT.JO             10.0    4.0    1.0
#            HLM.JO              1.0    1.0   -1.0
# 2013-03-05 GRT.JO              1.0    4.0    1.0
#            SHP.JO             10.0    1.0    1.0
# 2013-03-08 HLM.JO              1.0    1.0   -1.0
# ...                            ...    ...    ...
# 2017-12-22 TWR.JO              6.0    1.0    1.0
#            WBO.JO             10.0    2.0   -1.0
# 2017-12-27 CTA.JO              1.0    4.0   -1.0
#            MCZ.JO             10.0    1.0    1.0
#            RBP.JO              5.0    2.0   -1.0
#
# [66347 rows x 3 columns]

# %%
checkCV(X, 35, 240)
# Out:
# Fold 7 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-03-13
# End date: 2014-02-26
#
# Test: Length =  33
# Start date: 2014-02-27
# End date: 2014-04-15
# ----------------------------------------------------------------
# Fold 8 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-05-03
# End date: 2014-04-15
#
# Test: Length =  33
# Start date: 2014-04-16
# End date: 2014-06-06
# ----------------------------------------------------------------
# Fold 9 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-06-20
# End date: 2014-06-06
#
# Test: Length =  33
# Start date: 2014-06-09
# End date: 2014-07-24
# ----------------------------------------------------------------
# Fold 10 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-08-06
# End date: 2014-07-24
#
# Test: Length =  33
# Start date: 2014-07-25
# End date: 2014-09-09
# ----------------------------------------------------------------
# Fold 11 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-09-23
# End date: 2014-09-09
#
# Test: Length =  33
# Start date: 2014-09-10
# End date: 2014-10-27
# ----------------------------------------------------------------
# Fold 12 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-11-08
# End date: 2014-10-27
#
# Test: Length =  33
# Start date: 2014-10-28
# End date: 2014-12-11
# ----------------------------------------------------------------
# Fold 13 -------------------------------------------------------
# Train: Length = 240
# Start date: 2013-12-30
# End date: 2014-12-11
#
# Test: Length =  33
# Start date: 2014-12-12
# End date: 2015-02-02
# ----------------------------------------------------------------
# Fold 14 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-02-14
# End date: 2015-02-02
#
# Test: Length =  33
# Start date: 2015-02-03
# End date: 2015-03-19
# ----------------------------------------------------------------
# Fold 15 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-04-03
# End date: 2015-03-19
#
# Test: Length =  33
# Start date: 2015-03-20
# End date: 2015-05-11
# ----------------------------------------------------------------
# Fold 16 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-05-27
# End date: 2015-05-11
#
# Test: Length =  33
# Start date: 2015-05-12
# End date: 2015-06-26
# ----------------------------------------------------------------
# Fold 17 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-07-14
# End date: 2015-06-26
#
# Test: Length =  33
# Start date: 2015-06-29
# End date: 2015-08-13
# ----------------------------------------------------------------
# Fold 18 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-08-28
# End date: 2015-08-13
#
# Test: Length =  33
# Start date: 2015-08-14
# End date: 2015-09-30
# ----------------------------------------------------------------
# Fold 19 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-10-15
# End date: 2015-09-30
#
# Test: Length =  33
# Start date: 2015-10-01
# End date: 2015-11-16
# ----------------------------------------------------------------
# Fold 20 -------------------------------------------------------
# Train: Length = 240
# Start date: 2014-12-01
# End date: 2015-11-16
#
# Test: Length =  33
# Start date: 2015-11-17
# End date: 2016-01-05
# ----------------------------------------------------------------
# Fold 21 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-01-21
# End date: 2016-01-05
#
# Test: Length =  33
# Start date: 2016-01-06
# End date: 2016-02-19
# ----------------------------------------------------------------
# Fold 22 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-03-09
# End date: 2016-02-19
#
# Test: Length =  33
# Start date: 2016-02-22
# End date: 2016-04-11
# ----------------------------------------------------------------
# Fold 23 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-04-28
# End date: 2016-04-11
#
# Test: Length =  33
# Start date: 2016-04-12
# End date: 2016-05-30
# ----------------------------------------------------------------
# Fold 24 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-06-15
# End date: 2016-05-30
#
# Test: Length =  33
# Start date: 2016-05-31
# End date: 2016-07-15
# ----------------------------------------------------------------
# Fold 25 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-07-31
# End date: 2016-07-15
#
# Test: Length =  33
# Start date: 2016-07-18
# End date: 2016-09-02
# ----------------------------------------------------------------
# Fold 26 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-09-17
# End date: 2016-09-02
#
# Test: Length =  33
# Start date: 2016-09-05
# End date: 2016-10-19
# ----------------------------------------------------------------
# Fold 27 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-11-04
# End date: 2016-10-19
#
# Test: Length =  33
# Start date: 2016-10-20
# End date: 2016-12-05
# ----------------------------------------------------------------
# Fold 28 -------------------------------------------------------
# Train: Length = 240
# Start date: 2015-12-22
# End date: 2016-12-05
#
# Test: Length =  33
# Start date: 2016-12-06
# End date: 2017-01-24
# ----------------------------------------------------------------
# Fold 29 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-02-09
# End date: 2017-01-24
#
# Test: Length =  33
# Start date: 2017-01-25
# End date: 2017-03-10
# ----------------------------------------------------------------
# Fold 30 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-03-30
# End date: 2017-03-10
#
# Test: Length =  33
# Start date: 2017-03-13
# End date: 2017-05-03
# ----------------------------------------------------------------
# Fold 31 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-05-18
# End date: 2017-05-03
#
# Test: Length =  33
# Start date: 2017-05-04
# End date: 2017-06-20
# ----------------------------------------------------------------
# Fold 32 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-07-05
# End date: 2017-06-20
#
# Test: Length =  33
# Start date: 2017-06-21
# End date: 2017-08-04
# ----------------------------------------------------------------
# Fold 33 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-08-23
# End date: 2017-08-04
#
# Test: Length =  33
# Start date: 2017-08-07
# End date: 2017-09-21
# ----------------------------------------------------------------
# Fold 34 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-10-07
# End date: 2017-09-21
#
# Test: Length =  33
# Start date: 2017-09-22
# End date: 2017-11-08
# ----------------------------------------------------------------
# Fold 35 -------------------------------------------------------
# Train: Length = 240
# Start date: 2016-11-23
# End date: 2017-11-08
#
# Test: Length =  33
# Start date: 2017-11-09
# End date: 2017-12-27
# ----------------------------------------------------------------

# %%
clf = LogisticRegression(random_state=42)
predictions, probabilities = modelFit(clf, X, y, cv = 35, max_train_size = 240)

# %%
probs = probabilities.loc[:, 1]
probs.name = 'factor'
factor = pd.DataFrame(probs) 
factor.index.set_names(['date', 'symbol'], inplace = True)
factor
# Out:
#                      factor
# date       symbol
# 2014-02-27 ABG.JO  0.507314
#            ACT.JO  0.501967
#            ADH.JO  0.503115
#            ADI.JO  0.501202
#            AFX.JO  0.499102
# ...                     ...
# 2017-12-22 TWR.JO  0.488991
#            WBO.JO  0.497112
# 2017-12-27 CTA.JO  0.502514
#            MCZ.JO  0.491542
#            RBP.JO  0.493923
#
# [57337 rows x 1 columns]

# %%
clf_factor_data = getCleanFactor(factor, forward_returns, quantiles = 5)
clf_factor_data
# Out:
# Dropped 0.0% entries from factor data: 0.0% in forward returns computation and 0.0% in binning phase (set max_loss=0 to see potentially suppressed Exceptions).
# max_loss is 45.0%, not exceeded: OK!
#                             1D    factor  factor_quantile
# date       asset
# 2014-02-27 ACT.JO    -0.008439  0.501967              2.0
# 2014-03-03 ACT.JO    -0.042553  0.501967              2.0
# 2014-03-07 ACT.JO     0.022222  0.497954              1.0
# 2014-03-20 ACT.JO    -0.036957  0.501584              2.0
# 2014-03-24 ACT.JO    -0.051919  0.499102              1.0
# ...                        ...       ...              ...
# 2017-12-14 STXWDM.JO -0.030055  0.488354              1.0
# 2017-12-15 STXWDM.JO -0.008451  0.487079              1.0
# 2017-12-18 STXWDM.JO -0.025284  0.486441              1.0
# 2017-12-19 STXWDM.JO -0.003206  0.486441              1.0
# 2017-12-22 STXWDM.JO  0.000000  0.487079              1.0
#
# [57337 rows x 3 columns]

# %%
InformationTable(clf_factor_data)
# Out:
# Information Analysis
#                      1D
# IC Mean           0.022
# IC Std.           0.164
# Risk-Adjusted IC  0.133
# t-stat(IC)          NaN
# p-value(IC)         NaN
# IC Skew             NaN
# IC Kurtosis         NaN

# %%
plotFactorQuantileBars(clf_factor_data)

plotCumulativeReturns(clf_factor_data[clf_factor_data['factor_quantile'].isin([1, 5])])

plotQuantileCumulativeReturns(clf_factor_data)
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/alphalens/performance.py:398: UserWarning: 'freq' not set, using business day calendar
#   UserWarning)
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/alphalens/performance.py:398: UserWarning: 'freq' not set, using business day calendar
#   UserWarning)

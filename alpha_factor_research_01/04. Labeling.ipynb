# %%
import pandas as pd
import ta
import numpy as np
import pickle
import itertools
from datetime import datetime

from alphalens import utils, plotting, performance, tears

import mlfinlab as ml

from factor_library.volatility import atr

import pyfolio

import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %matplotlib inline
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/pyfolio/pos.py:28: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   ' to position notionals.'
# WARNING (theano.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %%
trainPrices = pickle.load(open('/home/ubuntu/projects/trading/data/Prices_clean.pkl', 'rb'))

# %%
data = trainPrices['WHL.JO'].copy()
data
# Out:
#                    high          low         open        close     volume  \
# Date
# 2013-01-01  6760.160156  6760.160156  6760.160156  6760.160156        0.0
# 2013-01-02  6895.359863  6586.870117  6854.419922  6679.229980  2105298.0
# 2013-01-03  6855.370117  6712.549805  6759.209961  6741.120117  3103630.0
# 2013-01-04  6878.220215  6707.790039  6735.399902  6878.220215  2293156.0
# 2013-01-07  6902.979980  6769.680176  6879.180176  6781.109863  1809340.0
# ...                 ...          ...          ...          ...        ...
# 2017-12-25  6293.000000  6293.000000  6293.000000  6293.000000        0.0
# 2017-12-26  6293.000000  6293.000000  6293.000000  6293.000000        0.0
# 2017-12-27  6360.000000  6242.000000  6290.000000  6329.000000  3542933.0
# 2017-12-28  6447.000000  6300.000000  6320.000000  6447.000000  2857012.0
# 2017-12-29  6535.000000  6370.000000  6400.000000  6515.000000    73001.0
#
#               adj_close
# Date
# 2013-01-01  5069.762207
# 2013-01-02  5009.068848
# 2013-01-03  5055.483887
# 2013-01-04  5158.302246
# 2013-01-07  5085.473145
# ...                 ...
# 2017-12-25  5665.954102
# 2017-12-26  5665.954102
# 2017-12-27  5698.367188
# 2017-12-28  5804.608887
# 2017-12-29  5865.833496
#
# [1300 rows x 6 columns]

# %%
data['close'].pct_change()
# Out:
# Date
# 2013-01-01         NaN
# 2013-01-02   -0.011972
# 2013-01-03    0.009266
# 2013-01-04    0.020338
# 2013-01-07   -0.014119
#                 ...
# 2017-12-25    0.000000
# 2017-12-26    0.000000
# 2017-12-27    0.005721
# 2017-12-28    0.018644
# 2017-12-29    0.010548
# Name: close, Length: 1300, dtype: float64

# %%
data['close'].shift(-1)
# Out:
# Date
# 2013-01-01    6679.229980
# 2013-01-02    6741.120117
# 2013-01-03    6878.220215
# 2013-01-04    6781.109863
# 2013-01-07    6842.040039
#                  ...
# 2017-12-25    6293.000000
# 2017-12-26    6329.000000
# 2017-12-27    6447.000000
# 2017-12-28    6515.000000
# 2017-12-29            NaN
# Name: close, Length: 1300, dtype: float64

# %%
pd.DataFrame(np.log(data['close']) - np.log(data['close'].shift(1))).ewm(14).std()['close']
# Out:
# Date
# 2013-01-01         NaN
# 2013-01-02         NaN
# 2013-01-03    0.015038
# 2013-01-04    0.016241
# 2013-01-07    0.016867
#                 ...
# 2017-12-25    0.018501
# 2017-12-26    0.017907
# 2017-12-27    0.017305
# 2017-12-28    0.017109
# 2017-12-29    0.016586
# Name: close, Length: 1300, dtype: float64

# %%
ml.util.get_daily_vol(data['close'].iloc[-20:], lookback=14)#.iloc[-20:]
# Out:
# Date
# 2017-12-06         NaN
# 2017-12-07    0.040483
# 2017-12-08    0.031640
# 2017-12-11    0.026228
# 2017-12-12    0.022005
# 2017-12-13    0.020150
# 2017-12-14    0.025284
# 2017-12-15    0.025300
# 2017-12-18    0.030752
# 2017-12-19    0.041405
# 2017-12-20    0.037607
# 2017-12-21    0.036664
# 2017-12-22    0.033568
# 2017-12-25    0.031308
# 2017-12-26    0.029173
# 2017-12-27    0.026941
# 2017-12-28    0.025441
# 2017-12-29    0.024359
# Name: close, dtype: float64

# %%
28 + 24 + 36 + 12
# Out:
# 100

# %%
def getLabels(datas,
              lookback = 5,
              num_days_ahead = 1,
              pt_sl = [1, 1],
              min_ret = 0.005,
              at_open = True):
    
    output = {}
    for symbol, data in datas.items():
        
        try:
            close = data['close']
            open = data['open']
            low = data['low']
            high = data['high']

            if len(close) > lookback: 

                
                
                daily_vol = ml.util.get_daily_vol(
                                close, 
                                lookback = lookback)

#                 log_returns = np.log(close) - np.log(close.shift(1))
#                 daily_vol = pd.DataFrame(log_returns).ewm(lookback).std().iloc[:, 0]
        
                if daily_vol.nunique() != 1:

                    cusum_events = ml.filters.cusum_filter(
                                        close,
                                        threshold = daily_vol.mean()) # 

                    data = data.reset_index()
                    data['event'] = np.where(data['Date'].isin(cusum_events), 1, 0)
                    data.set_index('Date', inplace = True)

                    vertical_barriers = ml.labeling.add_vertical_barrier(
                                            t_events = cusum_events,
                                            close = close,
                                            num_days = num_days_ahead)

                    data['vertical_barriers'] = vertical_barriers

                    triple_barrier_events = ml.labeling.get_events(
                                    close = close,
                                    t_events = cusum_events,
                                    pt_sl = pt_sl,
                                    target = daily_vol,
                                    min_ret = min_ret,
                                    vertical_barrier_times = vertical_barriers,
                                    num_threads = 1,
                                    verbose = False)

                    data = pd.concat(
                        [data, triple_barrier_events], 
                        axis = 1).drop('trgt', axis = 1)

                    labels = ml.labeling.get_bins(
                        triple_barrier_events, close, open = open, at_open = at_open)

                    data = pd.concat([data, labels], axis = 1)
                    data.index.name = 'date'

                    data['profit_taking'] = data['pt'].mul(data['trgt'])
                    data['stop_loss'] = data['sl'].mul(data['trgt']).mul(-1)

                    data.reset_index(inplace = True)

                    data['holding_period'] = pd.to_datetime(data['t1'])\
                        .sub(pd.to_datetime(data['date']))\
                        .map(lambda x: x.days)
                    data.drop(['trgt', 'pt', 'sl'], axis = 1, inplace = True)
                    data.set_index('date', inplace = True)
                    
                    data['bin'] = np.where(data['ret'] > 0, 1,
                                          np.where(data['ret'] < 0, -1, data['bin']))

                    data.rename(columns = 
                                {'ret':'expected_return', 
                                 'bin':'label'
                                }, inplace = True) 
                    output[symbol] = data[data['label'] != 0]
                    
        except Exception as e:
            print(f"{symbol}: {e}")
    return output

# %%
data = {'MTN.JO':trainPrices['MTN.JO']}
out = getLabels(data, lookback = 14, num_days_ahead = 5, pt_sl = [1, 1], at_open = True)['MTN.JO']
out[out['event'] == 1]#value_counts() / len(out.dropna())
# Out:
#                high      low     open    close     volume     adj_close  \
# date
# 2013-01-10  18090.0  17573.0  18090.0  17662.0  4091984.0  10874.135742
# 2013-01-21  17948.0  17653.0  17672.0  17850.0  3200684.0  10989.884766
# 2013-01-30  17675.0  17321.0  17550.0  17350.0  4330669.0  10682.043945
# 2013-02-04  17871.0  17643.0  17755.0  17871.0  3673888.0  11002.811523
# 2013-02-05  18379.0  17800.0  17875.0  18367.0  7363505.0  11308.188477
# ...             ...      ...      ...      ...        ...           ...
# 2017-12-06  13142.0  12662.0  12772.0  13025.0  3968807.0  10807.081055
# 2017-12-11  12846.0  12499.0  12833.0  12586.0  3121684.0  10442.835938
# 2017-12-14  13179.0  12570.0  12570.0  13173.0  6229685.0  10929.879883
# 2017-12-20  13261.0  12901.0  13221.0  13046.0  4835771.0  10824.506836
# 2017-12-27  13570.0  13066.0  13249.0  13570.0  4275780.0  11259.278320
#
#             event vertical_barriers         t1  expected_return  label  \
# date
# 2013-01-10      1        2013-01-15 2013-01-15        -0.023834   -1.0
# 2013-01-21      1        2013-01-28 2013-01-23        -0.010135   -1.0
# 2013-01-30      1        2013-02-04 2013-02-01         0.020402    1.0
# 2013-02-04      1        2013-02-11 2013-02-05         0.029371    1.0
# 2013-02-05      1        2013-02-11 2013-02-06        -0.032663   -1.0
# ...           ...               ...        ...              ...    ...
# 2017-12-06      1        2017-12-11 2017-12-11        -0.031056   -1.0
# 2017-12-11      1        2017-12-18 2017-12-14         0.056253    1.0
# 2017-12-14      1        2017-12-19 2017-12-19         0.013103    1.0
# 2017-12-20      1        2017-12-25 2017-12-25         0.004228    1.0
# 2017-12-27      1               NaT        NaT              NaN    NaN
#
#             profit_taking  stop_loss  holding_period
# date
# 2013-01-10       0.016432  -0.016432             5.0
# 2013-01-21       0.014710  -0.014710             2.0
# 2013-01-30       0.010776  -0.010776             2.0
# 2013-02-04       0.011757  -0.011757             1.0
# 2013-02-05       0.018589  -0.018589             1.0
# ...                   ...        ...             ...
# 2017-12-06       0.015522  -0.015522             5.0
# 2017-12-11       0.015658  -0.015658             3.0
# 2017-12-14       0.020952  -0.020952             5.0
# 2017-12-20       0.024934  -0.024934             5.0
# 2017-12-27            NaN        NaN             NaN
#
# [386 rows x 14 columns]

# %%
cusumTrainPrices = getLabels(trainPrices, lookback = 14, num_days_ahead = 5, pt_sl = [1, 1], at_open = True)

# %%
pickle.dump(cusumTrainPrices, open('/home/ubuntu/projects/trading/data/cusumTrainPrices.pkl', 'wb'))
cusumTrainPrices = pickle.load(open('/home/ubuntu/projects/trading/data/cusumTrainPrices.pkl', 'rb'))

# %%
cusumTrainPrices['MTN.JO']
# Out:
#                high      low     open    close     volume     adj_close  \
# date
# 2013-01-01  17760.0  17760.0  17760.0  17760.0        0.0  10934.471680
# 2013-01-02  17974.0  17500.0  17900.0  17699.0  1727978.0  10896.917969
# 2013-01-03  17845.0  17440.0  17700.0  17675.0  4956273.0  10882.139648
# 2013-01-04  18109.0  17620.0  17700.0  18045.0  3895447.0  11109.942383
# 2013-01-07  18219.0  17822.0  18025.0  17831.0  2936696.0  10978.184570
# ...             ...      ...      ...      ...        ...           ...
# 2017-12-25  13065.0  13065.0  13065.0  13065.0        0.0  10840.269531
# 2017-12-26  13065.0  13065.0  13065.0  13065.0        0.0  10840.269531
# 2017-12-27  13570.0  13066.0  13249.0  13570.0  4275780.0  11259.278320
# 2017-12-28  13724.0  13300.0  13570.0  13524.0  4085005.0  11221.112305
# 2017-12-29  13660.0  13150.0  13549.0  13660.0  1399886.0  11333.954102
#
#             event vertical_barriers  t1  expected_return  label  \
# date
# 2013-01-01      0               NaT NaT              NaN    NaN
# 2013-01-02      0               NaT NaT              NaN    NaN
# 2013-01-03      0               NaT NaT              NaN    NaN
# 2013-01-04      0               NaT NaT              NaN    NaN
# 2013-01-07      0               NaT NaT              NaN    NaN
# ...           ...               ...  ..              ...    ...
# 2017-12-25      0               NaT NaT              NaN    NaN
# 2017-12-26      0               NaT NaT              NaN    NaN
# 2017-12-27      1               NaT NaT              NaN    NaN
# 2017-12-28      0               NaT NaT              NaN    NaN
# 2017-12-29      0               NaT NaT              NaN    NaN
#
#             profit_taking  stop_loss  holding_period
# date
# 2013-01-01            NaN        NaN             NaN
# 2013-01-02            NaN        NaN             NaN
# 2013-01-03            NaN        NaN             NaN
# 2013-01-04            NaN        NaN             NaN
# 2013-01-07            NaN        NaN             NaN
# ...                   ...        ...             ...
# 2017-12-25            NaN        NaN             NaN
# 2017-12-26            NaN        NaN             NaN
# 2017-12-27            NaN        NaN             NaN
# 2017-12-28            NaN        NaN             NaN
# 2017-12-29            NaN        NaN             NaN
#
# [1299 rows x 14 columns]

# %%
def getTarget(cusumTrainPrices):
    target = pd.DataFrame()
    for symbol, data in cusumTrainPrices.items():
        
        data = data[data['event'] == 1].copy()
        label = data[['label']]
        label['asset'] = symbol
        out = label.reset_index().set_index(['date', 'asset'])
        target = pd.concat([target, out])
        
    return target.sort_index(level = 'date')

# %%
target = getTarget(cusumTrainPrices)
target.dropna()
# Out:
# /home/ubuntu/.local/lib/python3.6/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
#                       label
# date       asset
# 2013-01-04 ACT.JO       1.0
#            AEE.JO       1.0
#            AFE.JO       1.0
#            AFT.JO       1.0
#            AFX.JO       1.0
# ...                     ...
# 2017-12-27 FBR.JO      -1.0
#            MCZ.JO       1.0
#            RBX.JO       1.0
#            STXDIV.JO   -1.0
#            TWR.JO       1.0
#
# [91604 rows x 1 columns]

# %%
target['label'].value_counts()
# Out:
#  1.0    46346
# -1.0    45258
# Name: label, dtype: int64

# %%
pickle.dump(target, open('/home/ubuntu/projects/trading/data/binary_target_5_day.pkl', 'wb'))

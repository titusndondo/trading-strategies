# %%
import pyfolio as pf
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 0.22.0

# %%
returns = pd.read_csv('bt_returns.csv')
positions = pd.read_csv('bt_positions.csv')
benchmark = pd.read_csv('bt_benchmark.csv')

# %%
pf.create_position_tear_sheet(returns, positions)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>RBP.JO</th>
#       <td>50.00%</td>
#     </tr>
#     <tr>
#       <th>GFI.JO</th>
#       <td>40.86%</td>
#     </tr>
#     <tr>
#       <th>NFTRCI.JO</th>
#       <td>36.97%</td>
#     </tr>
#     <tr>
#       <th>SAP.JO</th>
#       <td>30.63%</td>
#     </tr>
#     <tr>
#       <th>HCI.JO</th>
#       <td>30.30%</td>
#     </tr>
#     <tr>
#       <th>LEW.JO</th>
#       <td>29.06%</td>
#     </tr>
#     <tr>
#       <th>HDC.JO</th>
#       <td>27.72%</td>
#     </tr>
#     <tr>
#       <th>AFH.JO</th>
#       <td>27.70%</td>
#     </tr>
#     <tr>
#       <th>SPG.JO</th>
#       <td>27.65%</td>
#     </tr>
#     <tr>
#       <th>KIO.JO</th>
#       <td>25.70%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
# ...
